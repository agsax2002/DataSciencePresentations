# %%
#Run this code at the beginning of the presentation
from IPython.core.display import Image, display
from fig_code import plot_sgd_separator
from fig_code import plot_linear_regression
import seaborn; seaborn.set()
# %matplotlib inline

# %% [markdown]
# <small><i>This notebook was put together by **Andrew Greenhut** on **June 3rd 2015**.</i></small>

# %% [markdown]
# # <u>Predictive Analytics and Machine Learning Primer</u>

# %%
display(Image(filename='images/Predictive-Analytics.png'))

# %% [markdown]
# ## Goals of this Presentation

# %% [markdown]
# - **Introduce the basics of Machine Learning**, and some skills useful in practice.
# - **Demonstrate Predictive Analytics**, to give you ideas of how it can be applied.

# %% [markdown]
# Outline:
#
# **12:45 - 1:00** Basic Principles of Machine Learning
# * What is Machine Learning?
# * Machine learning - data requirements and steps
# * How can I use this?
#
# **1:00 - 1:15** Predictive Analytics Demo
# * Predicting Flower Type
# * Digit Recognition
#
# **1:15 - 1:30** Questions

# %% [markdown]
# ---

# %%
display(Image(filename='images/dashboard-snockered-624x418.png'))

# %% [markdown]
# ### What is Machine Learning?
#
# Machine Learning is computer program that **adapts to previously seen data**.
#
# Output depends on the **algorithm** and a set of **tunable parameters** (known as "hyper-parameters")
#
# Most algorithms fit into two categories: **Supervised** or **Unsupervised**
# - **Supervised** learning uses a set of answers to **train** a model on known data, such that it can predict answers for new data.
#     - e.g. Regression, Classification
# * **Unsupervised** learning looks at all data to tell you general known things about it (not covered in this presentation)
#     - e.g. Clustering, Anomaly Detection
#
# There is no magic to Machine Learning. It is all **linear algebra** of matrices with the goal to minimize an <i>error function</i>

# %% [markdown]
# ### Supervised Regression Algorithm.
# The model has been **learned** from the training data, and can be used to predict the result of test data. This might seem like a trivial problem, but it is a basic example of a type of operation that is fundamental to machine learning tasks.

# %%
plot_linear_regression()

# %% [markdown]
# ### Supervised Classification Algorithm.
# If you were to drop another point onto the plane which is unlabeled, this algorithm could now predict whether it's a blue or a red point.

# %%
plot_sgd_separator()

# %% [markdown]
# ### Machine learning - data requirements and steps
#
# Most machine learning algorithms implemented expect data to be stored in a **table (or matrix)**. The size of the table is expected to be `[n_samples (rows), n_features (columns)]`
#
# - **n_samples:**   The number of samples: each sample is an item to process (e.g. classify).
#   A sample can be a document, a picture, a sound, a video, a user,
#   a row in database or CSV file,
#   or whatever you can describe with a fixed set of quantitative traits.
# - **n_features:**  The number of features or distinct traits that can be used to describe each
#   item in a quantitative manner.  Features are generally continuous, but may be dates, boolean or
#   discrete-valued in some cases.
#
# The number of features can be very high dimensional (e.g. millions of features) with most of them being zeros for a given sample.

# %%
display(Image(filename='images/images.png'))

# %%
display(Image(filename='images/supervised_learning_flowchart.png'))

# %% [markdown]
# ### How Can I Use This?
#
# asdfadf

# %% [markdown]
# ---

# %%
#Demo Iris classification and digit recognition

# %%
display(Image(filename='images/cheat_sheet.png'))
